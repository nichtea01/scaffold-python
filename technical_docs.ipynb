# %% [markdown]
# <a href="https://colab.research.google.com/github/nichtea01/scaffold-python/blob/main/technical_docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %% [markdown]
# ### Heading for Documentation
#
# See GitHub doc [Demo Markdown Doc](https://github.com/nichtea01/technical-discussion-demo/blob/main/README.md) | [GitHub Markdown Doc](https://guides.github.com/features/mastering-markdown/) | [Github Docs](https://docs.github.com/en)

# %%
def helloworld():
    return("hello world")
helloworld()
# Out:
# 'hello world'

# %%
def gistdemo():
    return 10
gistdemo()
# Out:
# 10

# %% [markdown]
# ## EDA

# %% [markdown]
# ### this is a markdown 2nd heading
#
# * list item 1
# * list itme 2
# * list item 3

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Conclusion
